# %% [markdown]
# ## Gridded Runoff Field Remapping for mizuRoute (CLM)
#
# This section outlines the steps required to prepare a runoff input file for mizuRoute, converting runoff data from either structured or unstructured meshes into river network routing subbasins using **EASYMORE** without the need for a separate remapping file.
#
# ### Overview
#
# To generate the remapped runoff file(s), users should first call the **EASYMORE `nc_remapper`** function, providing:
#
# - A **target shapefile** (e.g., river network subbasins), and
# - A **sample NetCDF file** containing the runoff field.
#
# ### Notes on Large River Networks
#
# If the target river network topology is extensive or divided into multiple regions (e.g., continents or sub-regions), the remap runoff file(s) can be generated **separately for each part**, and later **merged into a single remap file**.
#
# ### mizuRoute Control File
#
# For the example provided here, the mizuRoute control file, including runoff file(s) are as below:
#
# ```
# ! ****************************************************************************************************************************
# ! DEFINE RUNOFF FILE
# ! ----------------------------------
# <fname_qsim>               CLM_MedicineHat_remapped_CLM_sample.nc  ! name of netCDF containing the HRU runoff, can be with * or ?
# <vname_qsim>               QRUNOFF                ! name of HRU runoff variable
# <vname_time>               time                   ! name of time variable in the runoff file
# <dname_time>               time                   ! name of time dimension
# <vname_hruid>              ID                     ! name of variable that includes HRU IDs
# <dname_hruid>              ID                     ! name of runoff dimension
# <units_qsim>               mm/s                   ! units of runoff
# <dt_qsim>                  86400                  ! time interval of the runoff
# ! ****************************************************************************************************************************
# ! DEFINE RUNOFF MAPPING FILE
# ! ----------------------------------
# ! can be left empty as the default is False - No remapping
# ! ****************************************************************************************************************************
# ```

# %%
# loading EASYMORE and other packages
from easymore import Easymore

# %%
# Generate easymore remapping file
esmr = Easymore()
# Set parameters individually
esmr.case_name            = "CLM_MedicineHat"
esmr.source_nc            = "../data/runoff/CLM/CLM_sampl*.nc"
esmr.var_names            = ["QRUNOFF"]
esmr.var_lon              = "lon"
esmr.var_lat              = "lat"
esmr.var_time             = "time"
esmr.target_shp           = "../data/subbasins/South_Saskatchewan_MedicineHat.shp"
esmr.target_shp_ID        = "COMID"
esmr.output_dir           = "../output/"
esmr.temp_dir             = "../temporary/"
# execute EASYMORE
esmr.nc_remapper()
# Out:
# EASYMORE version 2.0.0 is initiated.
# no author name is provided.
# EASYMORE will remap variable  QRUNOFF  from source file to variable  QRUNOFF  in remapped netCDF file
# EASYMORE detects that the variables from the netCDF files are identicalin dimensions of the variables and latitude and longitude
# EASYMORE detects that all the variables have dimensions of:
# ['time', 'lat', 'lon']
# EASYMORE detects that the longitude variables has dimensions of:
# ['lon']
# EASYMORE detects that the latitude variables has dimensions of:
# ['lat']
# --CREATING-REMAPPING-FILE--
# Started at date and time 2025-04-07 15:18:25.964854
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that the field for ID is provided in sink/target shapefile
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in WGS84 projection;
# for better appximation use the easymore equal area centroid function to preprocess target shapefile
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE saved target shapefile for EASYMORE claculation as:
# ../temporary/CLM_MedicineHat_target_shapefile.shp
# EASYMORE detects case 1 - regular lat/lon
# ../temporary/CLM_MedicineHat_source_shapefile.shp
# EASYMORE created the shapefile from the netCDF file and saved it here:
# EASMORE detects that target shapefile is outside the boundary of source netCDF file  and therefore correction for longitude values -180 to 180 or 0 to 360 if correction_shp_lon  flag is set to True [default is True]
# correcting target shapefile
# correcting source shapefile
# EASYMORE detects that the shapefile is in region 180 to 360 and correct by moving -360
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages
feature 60 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 60 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 117621212.908785433 of field AINT of feature 60 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 138365600.658756316 of field AS1 of feature 61 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78784394 of field AS2 of feature 61 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 128761326.682696432 of field AINT of feature 61 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 138365600.658756316 of field AS1 of feature 62 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 62 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113880071.109536871 of field AS1 of feature 63 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37928391 of field AS2 of feature 63 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113880071.109536424 of field AINT of feature 63 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 272524667.662452817 of field AS1 of feature 64 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02756333 of field AS2 of feature 64 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 272524667.662452817 of field AS1 of feature 65 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 65 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 272524667.662452817 of field AS1 of feature 66 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 66 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 272524667.662452817 of field AS1 of feature 67 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20578003 of field AS2 of feature 67 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 68 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113938047.329838827 of field AS1 of feature 69 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 69 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113938047.329838827 of field AS1 of feature 70 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 70 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37928391 of field AS2 of feature 71 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02756333 of field AS2 of feature 72 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78784394 of field AS2 of feature 73 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 196087891.496233165 of field AS1 of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 192161353.108185202 of field AINT of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 196087891.496233165 of field AS1 of feature 75 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 75 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 122101292.343612611 of field AS1 of feature 76 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 76 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 122101292.343612611 of field AS1 of feature 77 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37928391 of field AS2 of feature 77 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 78 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 79 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 159268114.559135884 of field AS1 of feature 80 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 80 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 143157243.199508131 of field AINT of feature 80 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 159268114.559135884 of field AS1 of feature 81 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 81 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 159268114.559135884 of field AS1 of feature 82 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 82 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# ...
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 726 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 727 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02756333 of field AS2 of feature 728 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 123618614.042313546 of field AS1 of feature 729 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20578003 of field AS2 of feature 729 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 123618614.042313546 of field AINT of feature 729 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 139447922.809635758 of field AS1 of feature 730 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1920940484.26482868 of field AS2 of feature 730 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 108540093.506114632 of field AINT of feature 730 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 139447922.809635758 of field AS1 of feature 731 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 731 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 732 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2024234195.25625515 of field AS2 of feature 733 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2024234195.25625515 of field AS2 of feature 734 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 119765951.909427911 of field AS1 of feature 735 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 735 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 119765951.909427911 of field AS1 of feature 736 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 736 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 128522316.853283972 of field AS1 of feature 737 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 737 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 128522316.853284016 of field AINT of feature 737 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 239169013.930053324 of field AS1 of feature 738 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 738 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 239169013.930053324 of field AS1 of feature 739 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 739 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 239169013.930053324 of field AS1 of feature 740 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 740 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 239169013.930053324 of field AS1 of feature 741 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 741 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 135051545.175075024 of field AINT of feature 741 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214405614.974054307 of field AS1 of feature 742 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 742 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 201116715.639820546 of field AINT of feature 742 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 214405614.974054307 of field AS1 of feature 743 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 743 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 166764411.98204729 of field AS1 of feature 744 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2024234195.25625515 of field AS2 of feature 744 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 164577297.600180864 of field AINT of feature 744 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 166764411.98204729 of field AS1 of feature 745 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 745 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 746 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 747 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 217158738.290252119 of field AS1 of feature 748 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1941909312.02748847 of field AS2 of feature 748 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 217158738.290252119 of field AS1 of feature 749 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 749 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 216388694.232371032 of field AINT of feature 749 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113724166.964912608 of field AS1 of feature 750 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37928391 of field AS2 of feature 750 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 113724166.964912608 of field AS1 of feature 751 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 2003888523.37920666 of field AS2 of feature 751 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 108866931.413273618 of field AINT of feature 751 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 752 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 753 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1983384831.78776741 of field AS2 of feature 754 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20570421 of field AS2 of feature 755 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 1962724597.20578003 of field AS2 of feature 756 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/shg096/Desktop/CanadaAon/env/aon_venv/lib/python3.9/site-packages/easymore/remapper.py:558: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   attr = attr.drop('index')
# Ended at date and time 2025-04-07 15:20:49.566288
# It took 143.601434 seconds to finish creating of the remapping file
# ---------------------------
# ------REMAPPING------
# netcdf output file will be compressed at level 4
# Remapping ../data/runoff/CLM/CLM_sample.nc to ../output/CLM_MedicineHat_remapped_CLM_sample.nc
# Started at date and time 2025-04-07 15:20:51.117080
# Ended at date and time 2025-04-07 15:20:51.144279
# It took 0.027199 seconds to finish the remapping of variable(s)
# ---------------------
# ---------------------
